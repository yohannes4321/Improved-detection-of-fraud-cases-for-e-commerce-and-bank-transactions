# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np 
import seaborn as sns

# %%
df=pd.read_csv('../Data/raw/creditcard.csv')
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.654067e-16 -3.568593e-16  2.578648e-16  4.473266e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   5.340915e-16  1.683437e-15 -3.660091e-16 -1.227390e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
data_fraud=df['Class'].value_counts()
plt.Figure(figsize=(10,8))

sns.barplot(data=data_fraud)
plt.title('Fraud and non Fraud distribution')
plt.xlabel('Class')
plt.ylabel('number of Transaction')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# very baised data 0.172 % of fraud data and 99.9 % non fraud data hily baised data

# %%
import numpy as np
df['Hour'] = np.floor(df['Time'] / 3600)  
legit_df = df[df['Class'] == 0]
fraud_df = df[df['Class'] == 1]
legit_counts = legit_df.groupby('Hour')['Class'].count()
fraud_counts = fraud_df.groupby('Hour')['Class'].count()
hourly_distribution = pd.DataFrame({
    'Legit': legit_counts,
    'Fraud': fraud_counts
}).fillna(0)  
import matplotlib.pyplot as plt
import seaborn as sns

fig,(axs1,axs2)=plt.subplots(ncols=2,figsize=(15, 8))
sns.lineplot(ax=axs1,data=hourly_distribution, x='Hour',y='Legit')
sns.lineplot(ax=axs2,data=hourly_distribution, x='Hour',y='Fraud',color='red')
axs1.set_title('Number of Non Fraud Transactions by Hour')
axs2.set_title('Number of Fraud Transactions by Hour')

plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_19700\3024391041.py:21: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# Check for the Outlier

# %%
fig,(axis1,axis2)=plt.subplots(ncols=2,figsize=(15,8))
sns.boxplot(ax=axis1,x='Class',y='Amount',hue='Class',data=legit_df)
sns.boxplot(ax=axis2,x='Class',y='Amount',hue='Class',data=fraud_df)
axis1.set_title(" Non Fraud data outlier detection")
axis2.set_title(" Fraud data outlier detection ")
# Out:
# Text(0.5, 1.0, ' Fraud data outlier detection ')

# %% [markdown]
# Scatter plot between fraud data and time

# %%
plt.Figure(figsize=(16,10))
sns.scatterplot(data=fraud_df,x='Time',y='Amount')
plt.xlabel('Time of Fraud data')
plt.ylabel('Amount for Fraud Data')
plt.title('Fraud Amount with Time')
plt.xticks(rotation=45)
plt.show()

# %%
for col in final_df.select_dtypes(include=['number']).columns:
    q1=final_df[col].quantile(0.25)
    q3=final_df[col].quantile(0.75)
    IQR=q1-q3
    lowerbound=q1-IQR
    upperbound=q3+IQR
    final_df[col]=final_df[col].clip(lower=lowerbound,upper=upperbound)

# %% [markdown]
# Feauture density extraction

# %%
features = df.columns.values
num_features = len(features)
plt.figure(figsize=(20, 40))  # Adjust size as needed

for i, feature in enumerate(features):
    plt.subplot((num_features // 4) + 1, 4, i + 1)
    sns.kdeplot(fraud_df[feature], label='Fraud')
    sns.kdeplot(legit_df[feature], label='Non Fraud')
    plt.title(f'Density Plot for {feature}')
    plt.legend()

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_19700\1905930532.py:7: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(fraud_df[feature], label='Fraud')
# C:\Users\Hp\AppData\Local\Temp\ipykernel_19700\1905930532.py:8: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(legit_df[feature], label='Non Fraud')
# C:\Users\Hp\AppData\Local\Temp\ipykernel_19700\1905930532.py:10: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
#  What is a Density Plot?
#
#  A density plot is just a smooth version of a histogram.
# overlapping are not usefull that has the same dsistribution
#
# but non overlap like V4 ,V11,V18,V17,V16,V14 THIS feature help in identifying the fraud

# %%
corr_mat=df.corr()
plt.figure(figsize=(20,14))
sns.heatmap(corr_mat,annot=True,cmap='coolwarm')
plt.show()

# %%
X=final_df.drop(['V22','V23','V24','V25','V26'],axis=1)
Y=final_df['Class']
columns_x=X.columns
from sklearn.preprocessing import MinMaxScaler
m=MinMaxScaler()
X_scaled=m.fit_transform(X)
X=pd.DataFrame(X_scaled,columns=columns_x)
X.head()
# Out:
#        Time        V1        V2        V3        V4        V5        V6  \
# 0  0.409964  1.000000  0.254208  0.831412  0.200414  0.915280  0.275965
# 1  0.050236  0.502493  0.455441  1.000000  0.195346  0.878339  0.762824
# 2  0.101788  0.607745  0.000000  1.000000  0.000000  0.495761  0.960891
# 3  0.794797  0.693184  0.414819  0.770813  0.028364  0.859335  0.141249
# 4  0.500008  1.000000  0.180655  1.000000  0.926742  0.819999  1.000000
#
#          V7        V8        V9  ...       V16       V17       V18       V19  \
# 0  1.000000  0.000000  0.871960  ...  1.000000  1.000000  0.974686  0.206653
# 1  1.000000  0.337635  0.623853  ...  0.918461  0.863816  1.000000  0.944359
# 2  0.703474  0.184677  0.000000  ...  0.722889  1.000000  1.000000  1.000000
# 3  1.000000  0.333572  0.865008  ...  0.991481  1.000000  1.000000  0.166861
# 4  0.697276  0.426439  1.000000  ...  1.000000  0.875363  1.000000  0.000000
#
#         V20       V21       V27       V28    Amount  Class
# 0  0.200128  0.000000  0.054878  0.331466  0.000000    0.0
# 1  0.164351  0.451481  0.000000  0.000000  0.030361    0.0
# 2  0.390498  0.041399  0.437477  1.000000  0.139864    0.0
# 3  0.028357  0.638693  0.075525  0.371271  0.564923    0.0
# 4  0.000000  0.330908  0.082888  0.053153  0.000000    0.0
#
# [5 rows x 26 columns]

# %%
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,roc_auc_score
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
models={
    'Logistric Regression':LogisticRegression(max_iter=1000),
    'RandomForestClassifier':RandomForestClassifier(n_estimators=100,random_state=42,class_weight='balanced')

}
result=[]
for name,model in models.items():
    model.fit(x_train,y_train)
    predict=model.predict(x_test)
    accuracy=accuracy_score(y_test,predict)
    prec=precision_score(y_test,predict)
    rec=recall_score(y_test,predict)
    f1=f1_score(y_test,predict)
    roc_auc=roc_auc_score(y_test,predict)
    result.append((name,accuracy,prec,rec,f1,roc_auc))
data=pd.DataFrame(result,columns=['Model_name','Acuracy','Preceision','Recall','F1-score','ROC AUC SCORE'])
data.head()
# Out:
#                Model_name  Acuracy  Preceision  Recall  F1-score
# 0    Logistric Regression      1.0         1.0     1.0       1.0
# 1  RandomForestClassifier      1.0         1.0     1.0       1.0
