# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np 
import seaborn as sns

# %%
df=pd.read_csv('../Data/raw/creditcard.csv')

# %%
df['Class'].unique()
# Out:
# array([0, 1])

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
data_fraud=df['Class'].value_counts()
plt.Figure(figsize=(10,8))

sns.barplot(data=data_fraud)
plt.title('Fraud and non Fraud distribution')
plt.xlabel('Class')
plt.ylabel('number of Transaction')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df['Class'].unique()
# Out:
# array([0, 1])

# %% [markdown]
# very baised data 0.172 % of fraud data and 99.9 % non fraud data hily baised data

# %%
import numpy as np
df['Hour'] = np.floor(df['Time'] / 3600)  
legit_df = df[df['Class'] == 0]
fraud_df = df[df['Class'] == 1]
legit_counts = legit_df.groupby('Hour')['Class'].count()
fraud_counts = fraud_df.groupby('Hour')['Class'].count()
hourly_distribution = pd.DataFrame({
    'Legit': legit_counts,
    'Fraud': fraud_counts
}).fillna(0)  
import matplotlib.pyplot as plt
import seaborn as sns

fig,(axs1,axs2)=plt.subplots(ncols=2,figsize=(15, 8))
sns.lineplot(ax=axs1,data=hourly_distribution, x='Hour',y='Legit')
sns.lineplot(ax=axs2,data=hourly_distribution, x='Hour',y='Fraud',color='red')
axs1.set_title('Number of Non Fraud Transactions by Hour')
axs2.set_title('Number of Fraud Transactions by Hour')

plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_4032\3024391041.py:21: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# Check for the Outlier

# %%
fig,(axis1,axis2)=plt.subplots(ncols=2,figsize=(15,8))
sns.boxplot(ax=axis1,x='Class',y='Amount',hue='Class',data=legit_df)
sns.boxplot(ax=axis2,x='Class',y='Amount',hue='Class',data=fraud_df)
axis1.set_title(" Non Fraud data outlier detection")
axis2.set_title(" Fraud data outlier detection ")
# Out:
# Text(0.5, 1.0, ' Fraud data outlier detection ')

# %% [markdown]
# Scatter plot between fraud data and time

# %%
plt.Figure(figsize=(16,10))
sns.scatterplot(data=fraud_df,x='Time',y='Amount')
plt.xlabel('Time of Fraud data')
plt.ylabel('Amount for Fraud Data')
plt.title('Fraud Amount with Time')
plt.xticks(rotation=45)
plt.show()

# %%
# for col in fraud_df.select_dtypes(include=['number']).columns:
#     q1=df[col].quantile(0.25)
#     q3=df[col].quantile(0.75)
#     IQR=q1-q3
#     lowerbound=q1-IQR
#     upperbound=q3+IQR
#     df[col]=df[col].clip(lower=lowerbound,upper=upperbound)

# %% [markdown]
# Feauture density extraction

# %%
features = df.columns.values
num_features = len(features)
plt.figure(figsize=(20, 40))  # Adjust size as needed

for i, feature in enumerate(features):
    plt.subplot((num_features // 4) + 1, 4, i + 1)
    sns.kdeplot(fraud_df[feature], label='Fraud')
    sns.kdeplot(legit_df[feature], label='Non Fraud')
    plt.title(f'Density Plot for {feature}')
    plt.legend()

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_4032\1905930532.py:7: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(fraud_df[feature], label='Fraud')
# C:\Users\Hp\AppData\Local\Temp\ipykernel_4032\1905930532.py:8: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(legit_df[feature], label='Non Fraud')
# C:\Users\Hp\AppData\Local\Temp\ipykernel_4032\1905930532.py:10: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
#  What is a Density Plot?
#
#  A density plot is just a smooth version of a histogram.
# overlapping are not usefull that has the same dsistribution
#
# but non overlap like V4 ,V11,V18,V17,V16,V14 THIS feature help in identifying the fraud

# %% [markdown]
# # Stratify we use for imblance data to split to train and train using the persentage

# %%
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import precision_score,recall_score,f1_score,roc_auc_score
from sklearn.model_selection import train_test_split
X=df.drop('Class',axis=1)
Y=df['Class']
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=42,stratify=Y)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import (confusion_matrix,f1_score,precision_recall_curve,auc,ConfusionMatrixDisplay)
x_train,x_test,y_train,y_test=train_test_split(X,Y,stratify=Y,test_size=0.2,random_state=42)
logistic = LogisticRegression(solver='liblinear', max_iter=1000)

rf=RandomForestClassifier()
from scipy.stats import loguniform
#hyperparameter optimization
import numpy as np
from sklearn.model_selection import RepeatedStratifiedKFold
cv=RepeatedStratifiedKFold(n_splits=10,n_repeats=3,random_state=42)
param_rf={
    'n_estimators':[10,50,100,200],
    'max_depth':[None,5,10,15],
 
 'class_weight': ['balanced'],
    'bootstrap':[True,False]
}
space = {
    'penalty': ['l1', 'l2'],
    'class_weight': ['balanced']
}

random_forest_search=RandomizedSearchCV(
    rf,
    param_rf,
    cv=5,
    n_iter=10,
    random_state=42
    )
logistic_search = RandomizedSearchCV(
    logistic,
    space,
    cv=cv,
    n_iter=4,  # You only have 2 combos, 4 is safe
    scoring='accuracy',
    random_state=42
)
model={
    'Logistic Regression':logistic_search,
    'random_forest':random_forest_search
    
}

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import (confusion_matrix, ConfusionMatrixDisplay,
                             f1_score, precision_recall_curve, auc)

# ----- Logistic Regression -----
log_model = LogisticRegression(class_weight='balanced', solver='liblinear')
log_model.fit(x_train, y_train)

y_pred_log = log_model.predict(x_test)
y_score_log = log_model.predict_proba(x_test)[:, 1]

# Confusion Matrix
cm_log = confusion_matrix(y_test, y_pred_log)
disp_log = ConfusionMatrixDisplay(cm_log)
disp_log.plot(cmap="Blues")
plt.title("Confusion Matrix: Logistic Regression")
plt.show()

# Precision-Recall Curve
precision_log, recall_log, _ = precision_recall_curve(y_test, y_score_log)
pr_auc_log = auc(recall_log, precision_log)
plt.figure(figsize=(8, 6))
plt.plot(recall_log, precision_log, label=f"Logistic (PR-AUC = {pr_auc_log:.3f})")
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title("Precision-Recall Curve: Logistic Regression")
plt.legend()
plt.grid(True)
plt.show()

# ----- Random Forest -----
rf_model = RandomForestClassifier(class_weight='balanced', random_state=42)
rf_model.fit(x_train, y_train)

y_pred_rf = rf_model.predict(x_test)
y_score_rf = rf_model.predict_proba(x_test)[:, 1]

# Confusion Matrix
cm_rf = confusion_matrix(y_test, y_pred_rf)
disp_rf = ConfusionMatrixDisplay(cm_rf)
disp_rf.plot(cmap="Blues")
plt.title("Confusion Matrix: Random Forest")
plt.show()

# Precision-Recall Curve
precision_rf, recall_rf, _ = precision_recall_curve(y_test, y_score_rf)
pr_auc_rf = auc(recall_rf, precision_rf)
plt.figure(figsize=(8, 6))
plt.plot(recall_rf, precision_rf, label=f"Random Forest (PR-AUC = {pr_auc_rf:.3f})")
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title("Precision-Recall Curve: Random Forest")
plt.legend()
plt.grid(True)
plt.show()

# ----- Summary -----
df_results = pd.DataFrame({
    "Model": ["Logistic Regression", "Random Forest"],
    "F1 Score": [f1_score(y_test, y_pred_log), f1_score(y_test, y_pred_rf)],
    "PR-AUC": [pr_auc_log, pr_auc_rf]
})

print(df_results.sort_values(by="PR-AUC", ascending=False))
# Out:
#                  Model  F1 Score    PR-AUC
# 1        Random Forest  0.839080  0.867032
# 0  Logistic Regression  0.112853  0.760610
